# %%
import pandas as pd
import os

pwd = os.getcwd()

print(f'path is {pwd} now ')

df = pd.read_csv('Quality_of_Service_5G.csv')
df
# Out:
# path is c:\Users\shrun\Project\Pythonproject now
#           Timestamp   User_ID   Application_Type Signal_Strength Latency  \
# 0    9/3/2023 10:00    User_1         Video_Call         -75 dBm   30 ms
# 1    9/3/2023 10:00    User_2         Voice_Call         -80 dBm   20 ms
# 2    9/3/2023 10:00    User_3          Streaming         -85 dBm   40 ms
# 3    9/3/2023 10:00    User_4  Emergency_Service         -70 dBm   10 ms
# 4    9/3/2023 10:00    User_5      Online_Gaming         -78 dBm   25 ms
# ..              ...       ...                ...             ...     ...
# 395  9/3/2023 10:06  User_396          Streaming        -110 dBm   61 ms
# 396  9/3/2023 10:06  User_397         Video_Call         -40 dBm   53 ms
# 397  9/3/2023 10:06  User_398    Video_Streaming        -113 dBm   58 ms
# 398  9/3/2023 10:06  User_399  Emergency_Service         -40 dBm    5 ms
# 399  9/3/2023 10:06  User_400       Web_Browsing        -113 dBm    0 ms
#
#     Required_Bandwidth Allocated_Bandwidth Resource_Allocation
# 0              10 Mbps             15 Mbps                 70%
# 1             100 Kbps            120 Kbps                 80%
# 2               5 Mbps              6 Mbps                 75%
# 3               1 Mbps            1.5 Mbps                 90%
# 4               2 Mbps              3 Mbps                 85%
# ..                 ...                 ...                 ...
# 395           1.3 Mbps            1.8 Mbps                 85%
# 396          14.5 Mbps           15.8 Mbps                 75%
# 397           1.0 Mbps            1.4 Mbps                 70%
# 398           0.4 Mbps            0.4 Mbps                 70%
# 399           0.1 Mbps            0.1 Mbps                 70%
#
# [400 rows x 8 columns]

# %% [markdown]
# 1. Data Pre-Processing :

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            400 non-null    object
#  1   User_ID              400 non-null    object
#  2   Application_Type     400 non-null    object
#  3   Signal_Strength      400 non-null    object
#  4   Latency              400 non-null    object
#  5   Required_Bandwidth   400 non-null    object
#  6   Allocated_Bandwidth  400 non-null    object
#  7   Resource_Allocation  400 non-null    object
# dtypes: object(8)
# memory usage: 25.1+ KB

# %%
df.isna().sum()
# Out:
# Timestamp              0
# User_ID                0
# Application_Type       0
# Signal_Strength        0
# Latency                0
# Required_Bandwidth     0
# Allocated_Bandwidth    0
# Resource_Allocation    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Resource_Allocation'] = df['Resource_Allocation'].str.replace('%','')
df
# Out:
#           Timestamp   User_ID   Application_Type Signal_Strength Latency  \
# 0    9/3/2023 10:00    User_1         Video_Call         -75 dBm   30 ms
# 1    9/3/2023 10:00    User_2         Voice_Call         -80 dBm   20 ms
# 2    9/3/2023 10:00    User_3          Streaming         -85 dBm   40 ms
# 3    9/3/2023 10:00    User_4  Emergency_Service         -70 dBm   10 ms
# 4    9/3/2023 10:00    User_5      Online_Gaming         -78 dBm   25 ms
# ..              ...       ...                ...             ...     ...
# 395  9/3/2023 10:06  User_396          Streaming        -110 dBm   61 ms
# 396  9/3/2023 10:06  User_397         Video_Call         -40 dBm   53 ms
# 397  9/3/2023 10:06  User_398    Video_Streaming        -113 dBm   58 ms
# 398  9/3/2023 10:06  User_399  Emergency_Service         -40 dBm    5 ms
# 399  9/3/2023 10:06  User_400       Web_Browsing        -113 dBm    0 ms
#
#     Required_Bandwidth Allocated_Bandwidth Resource_Allocation
# 0              10 Mbps             15 Mbps                  70
# 1             100 Kbps            120 Kbps                  80
# 2               5 Mbps              6 Mbps                  75
# 3               1 Mbps            1.5 Mbps                  90
# 4               2 Mbps              3 Mbps                  85
# ..                 ...                 ...                 ...
# 395           1.3 Mbps            1.8 Mbps                  85
# 396          14.5 Mbps           15.8 Mbps                  75
# 397           1.0 Mbps            1.4 Mbps                  70
# 398           0.4 Mbps            0.4 Mbps                  70
# 399           0.1 Mbps            0.1 Mbps                  70
#
# [400 rows x 8 columns]

# %%
df['User_ID'] = df['User_ID'].str.replace('User_','')
df
# Out:
#           Timestamp User_ID   Application_Type Signal_Strength Latency  \
# 0    9/3/2023 10:00       1         Video_Call         -75 dBm   30 ms
# 1    9/3/2023 10:00       2         Voice_Call         -80 dBm   20 ms
# 2    9/3/2023 10:00       3          Streaming         -85 dBm   40 ms
# 3    9/3/2023 10:00       4  Emergency_Service         -70 dBm   10 ms
# 4    9/3/2023 10:00       5      Online_Gaming         -78 dBm   25 ms
# ..              ...     ...                ...             ...     ...
# 395  9/3/2023 10:06     396          Streaming        -110 dBm   61 ms
# 396  9/3/2023 10:06     397         Video_Call         -40 dBm   53 ms
# 397  9/3/2023 10:06     398    Video_Streaming        -113 dBm   58 ms
# 398  9/3/2023 10:06     399  Emergency_Service         -40 dBm    5 ms
# 399  9/3/2023 10:06     400       Web_Browsing        -113 dBm    0 ms
#
#     Required_Bandwidth Allocated_Bandwidth Resource_Allocation
# 0              10 Mbps             15 Mbps                  70
# 1             100 Kbps            120 Kbps                  80
# 2               5 Mbps              6 Mbps                  75
# 3               1 Mbps            1.5 Mbps                  90
# 4               2 Mbps              3 Mbps                  85
# ..                 ...                 ...                 ...
# 395           1.3 Mbps            1.8 Mbps                  85
# 396          14.5 Mbps           15.8 Mbps                  75
# 397           1.0 Mbps            1.4 Mbps                  70
# 398           0.4 Mbps            0.4 Mbps                  70
# 399           0.1 Mbps            0.1 Mbps                  70
#
# [400 rows x 8 columns]

# %%
# Bandwidth contains 2 units : Kbps and Mbps, where Kbps=1000*Mbps
# Mbps : Convert to Kbps
# Kbps : Leave as it is

def mbps_to_kbps(value):  
    if 'Mbps' in value:
        n = float(value.replace(' Mbps',''))
        return str(n*1000)+' Kbps'
    else:
        return value


df['Required_Bandwidth'] = df['Required_Bandwidth'].map(mbps_to_kbps)
df['Allocated_Bandwidth'] = df['Allocated_Bandwidth'].map(mbps_to_kbps)

df
# Out:
#           Timestamp User_ID   Application_Type Signal_Strength Latency  \
# 0    9/3/2023 10:00       1         Video_Call         -75 dBm   30 ms
# 1    9/3/2023 10:00       2         Voice_Call         -80 dBm   20 ms
# 2    9/3/2023 10:00       3          Streaming         -85 dBm   40 ms
# 3    9/3/2023 10:00       4  Emergency_Service         -70 dBm   10 ms
# 4    9/3/2023 10:00       5      Online_Gaming         -78 dBm   25 ms
# ..              ...     ...                ...             ...     ...
# 395  9/3/2023 10:06     396          Streaming        -110 dBm   61 ms
# 396  9/3/2023 10:06     397         Video_Call         -40 dBm   53 ms
# 397  9/3/2023 10:06     398    Video_Streaming        -113 dBm   58 ms
# 398  9/3/2023 10:06     399  Emergency_Service         -40 dBm    5 ms
# 399  9/3/2023 10:06     400       Web_Browsing        -113 dBm    0 ms
#
#     Required_Bandwidth Allocated_Bandwidth Resource_Allocation
# 0         10000.0 Kbps        15000.0 Kbps                  70
# 1             100 Kbps            120 Kbps                  80
# 2          5000.0 Kbps         6000.0 Kbps                  75
# 3          1000.0 Kbps         1500.0 Kbps                  90
# 4          2000.0 Kbps         3000.0 Kbps                  85
# ..                 ...                 ...                 ...
# 395        1300.0 Kbps         1800.0 Kbps                  85
# 396       14500.0 Kbps        15800.0 Kbps                  75
# 397        1000.0 Kbps         1400.0 Kbps                  70
# 398         400.0 Kbps          400.0 Kbps                  70
# 399         100.0 Kbps          100.0 Kbps                  70
#
# [400 rows x 8 columns]

# %%
df['Required_Bandwidth'] = df['Required_Bandwidth'].str.replace(' Kbps','')
df['Allocated_Bandwidth'] = df['Allocated_Bandwidth'].str.replace(' Kbps','')
df
# Out:
#           Timestamp User_ID   Application_Type Signal_Strength Latency  \
# 0    9/3/2023 10:00       1         Video_Call         -75 dBm   30 ms
# 1    9/3/2023 10:00       2         Voice_Call         -80 dBm   20 ms
# 2    9/3/2023 10:00       3          Streaming         -85 dBm   40 ms
# 3    9/3/2023 10:00       4  Emergency_Service         -70 dBm   10 ms
# 4    9/3/2023 10:00       5      Online_Gaming         -78 dBm   25 ms
# ..              ...     ...                ...             ...     ...
# 395  9/3/2023 10:06     396          Streaming        -110 dBm   61 ms
# 396  9/3/2023 10:06     397         Video_Call         -40 dBm   53 ms
# 397  9/3/2023 10:06     398    Video_Streaming        -113 dBm   58 ms
# 398  9/3/2023 10:06     399  Emergency_Service         -40 dBm    5 ms
# 399  9/3/2023 10:06     400       Web_Browsing        -113 dBm    0 ms
#
#     Required_Bandwidth Allocated_Bandwidth Resource_Allocation
# 0              10000.0             15000.0                  70
# 1                  100                 120                  80
# 2               5000.0              6000.0                  75
# 3               1000.0              1500.0                  90
# 4               2000.0              3000.0                  85
# ..                 ...                 ...                 ...
# 395             1300.0              1800.0                  85
# 396            14500.0             15800.0                  75
# 397             1000.0              1400.0                  70
# 398              400.0               400.0                  70
# 399              100.0               100.0                  70
#
# [400 rows x 8 columns]

# %%
df['Latency'] = df['Latency'].str.replace(' ms','')
df
# Out:
#           Timestamp User_ID   Application_Type Signal_Strength Latency  \
# 0    9/3/2023 10:00       1         Video_Call         -75 dBm      30
# 1    9/3/2023 10:00       2         Voice_Call         -80 dBm      20
# 2    9/3/2023 10:00       3          Streaming         -85 dBm      40
# 3    9/3/2023 10:00       4  Emergency_Service         -70 dBm      10
# 4    9/3/2023 10:00       5      Online_Gaming         -78 dBm      25
# ..              ...     ...                ...             ...     ...
# 395  9/3/2023 10:06     396          Streaming        -110 dBm      61
# 396  9/3/2023 10:06     397         Video_Call         -40 dBm      53
# 397  9/3/2023 10:06     398    Video_Streaming        -113 dBm      58
# 398  9/3/2023 10:06     399  Emergency_Service         -40 dBm       5
# 399  9/3/2023 10:06     400       Web_Browsing        -113 dBm       0
#
#     Required_Bandwidth Allocated_Bandwidth Resource_Allocation
# 0              10000.0             15000.0                  70
# 1                  100                 120                  80
# 2               5000.0              6000.0                  75
# 3               1000.0              1500.0                  90
# 4               2000.0              3000.0                  85
# ..                 ...                 ...                 ...
# 395             1300.0              1800.0                  85
# 396            14500.0             15800.0                  75
# 397             1000.0              1400.0                  70
# 398              400.0               400.0                  70
# 399              100.0               100.0                  70
#
# [400 rows x 8 columns]

# %%
df['Signal_Strength'] = df['Signal_Strength'].str.replace(' dBm','')
df
# Out:
#           Timestamp User_ID   Application_Type Signal_Strength Latency  \
# 0    9/3/2023 10:00       1         Video_Call             -75      30
# 1    9/3/2023 10:00       2         Voice_Call             -80      20
# 2    9/3/2023 10:00       3          Streaming             -85      40
# 3    9/3/2023 10:00       4  Emergency_Service             -70      10
# 4    9/3/2023 10:00       5      Online_Gaming             -78      25
# ..              ...     ...                ...             ...     ...
# 395  9/3/2023 10:06     396          Streaming            -110      61
# 396  9/3/2023 10:06     397         Video_Call             -40      53
# 397  9/3/2023 10:06     398    Video_Streaming            -113      58
# 398  9/3/2023 10:06     399  Emergency_Service             -40       5
# 399  9/3/2023 10:06     400       Web_Browsing            -113       0
#
#     Required_Bandwidth Allocated_Bandwidth Resource_Allocation
# 0              10000.0             15000.0                  70
# 1                  100                 120                  80
# 2               5000.0              6000.0                  75
# 3               1000.0              1500.0                  90
# 4               2000.0              3000.0                  85
# ..                 ...                 ...                 ...
# 395             1300.0              1800.0                  85
# 396            14500.0             15800.0                  75
# 397             1000.0              1400.0                  70
# 398              400.0               400.0                  70
# 399              100.0               100.0                  70
#
# [400 rows x 8 columns]

# %%
#Convert datatypes 
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df['User_ID'] = df['User_ID'].astype('int')
df['Application_Type'] = df['Application_Type'].astype('str')
df['Signal_Strength'] = df['Signal_Strength'].astype('int')
df['Latency'] = df['Latency'].astype('int')
df['Required_Bandwidth'] = df['Required_Bandwidth'].astype('float')
df['Allocated_Bandwidth'] = df['Allocated_Bandwidth'].astype('float')
df['Resource_Allocation'] = df['Resource_Allocation'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Timestamp            400 non-null    datetime64[ns]
#  1   User_ID              400 non-null    int64
#  2   Application_Type     400 non-null    object
#  3   Signal_Strength      400 non-null    int64
#  4   Latency              400 non-null    int64
#  5   Required_Bandwidth   400 non-null    float64
#  6   Allocated_Bandwidth  400 non-null    float64
#  7   Resource_Allocation  400 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(1)
# memory usage: 25.1+ KB

# %%
df.head(10)
# Out:
#             Timestamp  User_ID     Application_Type  Signal_Strength  Latency  \
# 0 2023-09-03 10:00:00        1           Video_Call              -75       30
# 1 2023-09-03 10:00:00        2           Voice_Call              -80       20
# 2 2023-09-03 10:00:00        3            Streaming              -85       40
# 3 2023-09-03 10:00:00        4    Emergency_Service              -70       10
# 4 2023-09-03 10:00:00        5        Online_Gaming              -78       25
# 5 2023-09-03 10:00:00        6  Background_Download              -90       50
# 6 2023-09-03 10:00:00        7         Web_Browsing              -88       30
# 7 2023-09-03 10:00:00        8      IoT_Temperature              -95      100
# 8 2023-09-03 10:00:00        9      Video_Streaming              -82       35
# 9 2023-09-03 10:00:00       10        File_Download              -75       45
#
#    Required_Bandwidth  Allocated_Bandwidth  Resource_Allocation
# 0             10000.0              15000.0                   70
# 1               100.0                120.0                   80
# 2              5000.0               6000.0                   75
# 3              1000.0               1500.0                   90
# 4              2000.0               3000.0                   85
# 5               500.0                550.0                   70
# 6              1000.0               1000.0                   60
# 7                10.0                 15.0                   50
# 8              3000.0               3500.0                   80
# 9              2000.0               2000.0                   70

# %%
df.tail()
# Out:
#               Timestamp  User_ID   Application_Type  Signal_Strength  Latency  \
# 395 2023-09-03 10:06:00      396          Streaming             -110       61
# 396 2023-09-03 10:06:00      397         Video_Call              -40       53
# 397 2023-09-03 10:06:00      398    Video_Streaming             -113       58
# 398 2023-09-03 10:06:00      399  Emergency_Service              -40        5
# 399 2023-09-03 10:06:00      400       Web_Browsing             -113        0
#
#      Required_Bandwidth  Allocated_Bandwidth  Resource_Allocation
# 395              1300.0               1800.0                   85
# 396             14500.0              15800.0                   75
# 397              1000.0               1400.0                   70
# 398               400.0                400.0                   70
# 399               100.0                100.0                   70

# %%
new_df = df
new_df.to_csv("5G_QoS_modified.csv", index=False)
